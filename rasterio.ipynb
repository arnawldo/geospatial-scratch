# %%
import rasterio
from rasterio import plot
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
kla = rasterio.open(r'data/Kampala_veg_diff21.tif')

# %%
plot.show(kla)

# %%
kla.crs
# Out:
# CRS({'init': 'epsg:32636'})

# %%
kla.meta
# Out:
# {'count': 1,
#  'crs': CRS({'init': 'epsg:32636'}),
#  'driver': 'GTiff',
#  'dtype': 'int32',
#  'height': 1729,
#  'nodata': 2147483647.0,
#  'transform': Affine(120.0, 0.0, 361607.23819999956,
#        0.0, -120.0, 105375.70099999942),
#  'width': 1845}

# %%
import mplleaflet

# %%
ax = plot.show(kla)
mplleaflet.display(fig=ax.figure, crs=kla.crs)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-14-e6f210eb254f> in <module>()
#       1 ax = plot.show(kla)
# ----> 2 mplleaflet.display(fig=ax.figure, crs=kla.crs)
#
# /home/arnoldo/anaconda3/lib/python3.5/site-packages/mplleaflet/_display.py in display(fig, closefig, **kwargs)
#     151         plt.close(fig)
#     152
# --> 153     html = fig_to_html(fig, **kwargs)
#     154
#     155     # We embed everything in an iframe.
#
# /home/arnoldo/anaconda3/lib/python3.5/site-packages/mplleaflet/_display.py in fig_to_html(fig, template, tiles, crs, epsg, embed_links)
#      82     renderer = LeafletRenderer(crs=crs, epsg=epsg)
#      83     exporter = Exporter(renderer)
# ---> 84     exporter.run(fig)
#      85
#      86     attribution = _attribution + ' | ' + tiles[1]
#
# ...
